# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("weatherAUS.csv")

# %%
df.head(10)
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1  2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2  2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3  2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4  2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
# 5  2008-12-06   Albury     14.6     29.7       0.2          NaN       NaN
# 6  2008-12-07   Albury     14.3     25.0       0.0          NaN       NaN
# 7  2008-12-08   Albury      7.7     26.7       0.0          NaN       NaN
# 8  2008-12-09   Albury      9.7     31.9       0.0          NaN       NaN
# 9  2008-12-10   Albury     13.1     30.1       1.4          NaN       NaN
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Humidity3pm  Pressure9am  \
# 0           W           44.0          W  ...        22.0       1007.7
# ...

# %%
df.dtypes
# Out:
# Date              object
# Location          object
# MinTemp          float64
# MaxTemp          float64
# Rainfall         float64
# Evaporation      float64
# Sunshine         float64
# WindGustDir       object
# WindGustSpeed    float64
# WindDir9am        object
# WindDir3pm        object
# WindSpeed9am     float64
# WindSpeed3pm     float64
# Humidity9am      float64
# Humidity3pm      float64
# Pressure9am      float64
# Pressure3pm      float64
# Cloud9am         float64
# Cloud3pm         float64
# Temp9am          float64
# Temp3pm          float64
# RainToday         object
# RISK_MM          float64
# RainTomorrow      object
# dtype: object

# %%
df.loc[df["RainTomorrow"]=="Yes","RainTomorrow"]=1

# %%
df.loc[df["RainTomorrow"]=="No","RainTomorrow"]=0

# %%
df.head()
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1  2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2  2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3  2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4  2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Humidity3pm  Pressure9am  \
# 0           W           44.0          W  ...        22.0       1007.7
# 1         WNW           44.0        NNW  ...        25.0       1010.6
# 2         WSW           46.0          W  ...        30.0       1007.6
# 3          NE           24.0         SE  ...        16.0       1017.6
# 4           W           41.0        ENE  ...        33.0       1010.8
#
#    Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  RISK_MM  \
# ...

# %%
ds=df.groupby('Location')

# %%
datapts=[x[1] for x in ds]

# %%
datapts[0]
# Out:
#              Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 93856  2008-07-01  Adelaide      8.8     15.7       5.0          1.6
# 93857  2008-07-02  Adelaide     12.7     15.8       0.8          1.4
# 93858  2008-07-03  Adelaide      6.2     15.1       0.0          1.8
# 93859  2008-07-04  Adelaide      5.3     15.9       0.0          1.4
# 93860  2008-07-06  Adelaide     11.3     15.7       NaN          NaN
# ...           ...       ...      ...      ...       ...          ...
# 96941  2017-06-20  Adelaide      4.9     19.1       0.0          NaN
# 96942  2017-06-21  Adelaide      4.5     19.2       0.0          NaN
# 96943  2017-06-22  Adelaide      4.6     19.5       0.0          NaN
# 96944  2017-06-23  Adelaide      5.4     18.5       0.0          NaN
# 96945  2017-06-24  Adelaide      5.0     17.3       0.0          NaN
#
#        Sunshine WindGustDir  WindGustSpeed WindDir9am  ... Humidity3pm  \
# ...

# %%
new_data=[]
for doc in datapts:
    new=[]
    raint=list(doc["RainTomorrow"].values)
    new_doc=doc[0:len(doc)-4]
    print(len(new_doc))
    for y in range(5):
        new=[]
        for x in range(len(raint)-y):
            if sum(raint[x:x+y+1])>0:
                new.append(1)
            else:
                new.append(0)
        new_doc.loc[:,"rain_"+str(y+1)+"_days"]=new[0:len(new)-(4-y)]
    new_data.append(new_doc)
# Out:
# 3086
# 3012
# 3007
# 3027
# 2924
# 3024
# 3030
# 3157
# 2984
# 3414
# 2984
# /Users/jkachhadia/Documents/makeharvard/env/lib/python3.7/site-packages/pandas/core/indexing.py:844: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = _infer_fill_value(value)
# /Users/jkachhadia/Documents/makeharvard/env/lib/python3.7/site-packages/pandas/core/indexing.py:964: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s
# 2949
# 2939
# 3188
# 2976
# 3184
# 1555
# 3024
# 2431
# ...

# %%
new_data[0].tail()
# Out:
#              Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 96937  2017-06-16  Adelaide      9.8     14.8       0.2          NaN
# 96938  2017-06-17  Adelaide      6.0     16.8       1.4          NaN
# 96939  2017-06-18  Adelaide      8.0     16.9       0.2          NaN
# 96940  2017-06-19  Adelaide      5.2     19.4       0.0          NaN
# 96941  2017-06-20  Adelaide      4.9     19.1       0.0          NaN
#
#        Sunshine WindGustDir  WindGustSpeed WindDir9am  ... Temp9am  Temp3pm  \
# 96937       NaN         ENE           13.0         NE  ...    11.8     14.6
# 96938       NaN         WSW           15.0        NaN  ...     9.3     16.4
# 96939       NaN         WSW           13.0        NaN  ...    10.0     16.2
# 96940       NaN          NE           24.0        NaN  ...    10.0     18.9
# 96941       NaN           N           19.0         NE  ...    10.4     18.4
#
#        RainToday  RISK_MM  RainTomorrow  rain_1_days  rain_2_days  \
# ...

# %%
datapts[0].tail()
# Out:
#              Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 96941  2017-06-20  Adelaide      4.9     19.1       0.0          NaN
# 96942  2017-06-21  Adelaide      4.5     19.2       0.0          NaN
# 96943  2017-06-22  Adelaide      4.6     19.5       0.0          NaN
# 96944  2017-06-23  Adelaide      5.4     18.5       0.0          NaN
# 96945  2017-06-24  Adelaide      5.0     17.3       0.0          NaN
#
#        Sunshine WindGustDir  WindGustSpeed WindDir9am  ... Humidity3pm  \
# 96941       NaN           N           19.0         NE  ...        37.0
# 96942       NaN         WSW           17.0        NaN  ...        52.0
# 96943       NaN           N           22.0        NaN  ...        29.0
# 96944       NaN         NNW           19.0        ENE  ...        44.0
# 96945       NaN           W           17.0        NaN  ...        54.0
#
#        Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  \
# ...

# %%
len(new_data)
# Out:
# 49

# %%
new_df=new_data[0]

# %%
for x in new_data[1:]:
    new_df=new_df.append(x)

# %%
len(new_df)
# Out:
# 141997

# %%
new_df
# Out:
#               Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 93856   2008-07-01  Adelaide      8.8     15.7       5.0          1.6
# 93857   2008-07-02  Adelaide     12.7     15.8       0.8          1.4
# 93858   2008-07-03  Adelaide      6.2     15.1       0.0          1.8
# 93859   2008-07-04  Adelaide      5.3     15.9       0.0          1.4
# 93860   2008-07-06  Adelaide     11.3     15.7       NaN          NaN
# ...            ...       ...      ...      ...       ...          ...
# 105959  2017-06-16   Woomera     11.6     18.9       0.2          NaN
# 105960  2017-06-17   Woomera      9.0     19.4       0.0          4.8
# 105961  2017-06-18   Woomera      8.3     19.0       0.0          2.2
# 105962  2017-06-19   Woomera      5.5     19.5       0.0          4.0
# 105963  2017-06-20   Woomera      5.6     19.7       0.0          2.2
#
#         Sunshine WindGustDir  WindGustSpeed WindDir9am  ... Temp9am  Temp3pm  \
# ...

# %%
new_df.to_csv("forecast.csv")

# %%
new_df["rain_5_days"].describe()
# Out:
# count    141997.000000
# mean          0.580104
# std           0.493543
# min           0.000000
# 25%           0.000000
# 50%           1.000000
# 75%           1.000000
# max           1.000000
# Name: rain_5_days, dtype: float64

# %%
new_df.columns
# Out:
# Index(['Date', 'Location', 'MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation',
#        'Sunshine', 'WindGustDir', 'WindGustSpeed', 'WindDir9am', 'WindDir3pm',
#        'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm',
#        'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'Temp9am',
#        'Temp3pm', 'RainToday', 'RISK_MM', 'RainTomorrow', 'rain_1_days',
#        'rain_2_days', 'rain_3_days', 'rain_4_days', 'rain_5_days'],
#       dtype='object')

# %%
X=new_df.copy()

# %%
# del X["Date"]
# del X["Location"]
# del X["RainTomorrow"]
len(X)
# Out:
# 141997

# %%
# del X["WindGustDir"],X["WindDir9am"],X["WindDir3pm"],

# %%
X.loc[X["RainToday"]=="Yes","RainToday"]=1
X.loc[X["RainToday"]=="No","RainToday"]=0

# %%
X=X[['MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation',
       'Sunshine', 'WindGustSpeed',
       'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm',
       'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'Temp9am',
       'Temp3pm', 'RainToday', 'RISK_MM',"rain_2_days"]]

# %%
X.columns
# Out:
# Index(['MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation', 'Sunshine',
#        'WindGustSpeed', 'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am',
#        'Humidity3pm', 'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm',
#        'Temp9am', 'Temp3pm', 'RainToday', 'RISK_MM', 'rain_2_days'],
#       dtype='object')

# %%
X=X.dropna()
y=X["rain_2_days"]
del X["rain_2_days"]

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
import time
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
t0=time.time()
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.25)
clf_rf = RandomForestClassifier(n_estimators=100, max_depth=10,random_state=0)
clf_rf.fit(X_train,y_train)
y_pred = clf_rf.predict(X_test)
score = accuracy_score(y_test,y_pred)
print('Accuracy :',score)
print('Time taken :' , time.time()-t0)
# Out:
# Accuracy : 0.8768001102459864
# Time taken : 3.599414110183716

# %%
from sklearn.linear_model import LogisticRegression
t0=time.time()
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2)
clf_logreg = LogisticRegression(random_state=0)
clf_logreg.fit(X_train,y_train)
y_pred = clf_logreg.predict(X_test)
score = accuracy_score(y_test,y_pred)
print('Accuracy :',score)
print('Time taken :' , time.time()-t0)
# Out:
# Accuracy : 0.8649440137812231
# Time taken : 0.38877415657043457
# /Users/jkachhadia/Documents/makeharvard/env/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)

# %%
import pickle

# %%
for x in range(1,6):
    X=new_df.copy()
    X.loc[X["RainToday"]=="Yes","RainToday"]=1
    X.loc[X["RainToday"]=="No","RainToday"]=0
    X=X[['MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation',
           'Sunshine', 'WindGustSpeed',
           'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm',
           'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'Temp9am',
           'Temp3pm', 'RainToday', 'RISK_MM',"rain_"+str(x)+"_days"]]
    X=X.dropna()
    y=X["rain_"+str(x)+"_days"]
    del X["rain_"+str(x)+"_days"]
    print(X.columns)
    t0=time.time()
    X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.25)
    clf_rf = RandomForestClassifier(n_estimators=100, max_depth=10,random_state=0)
    clf_rf.fit(X_train,y_train)
    y_pred = clf_rf.predict(X_test)
    print(x)
    score = accuracy_score(y_test,y_pred)
    print('Accuracy :',score)
    print('Time taken :' , time.time()-t0)
    clf_rf.fit(X,y)
    filename="model_"+str(x)
    pickle.dump(clf_rf, open(filename, 'wb'))
# Out:
# Index(['MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation', 'Sunshine',
#        'WindGustSpeed', 'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am',
#        'Humidity3pm', 'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm',
#        'Temp9am', 'Temp3pm', 'RainToday', 'RISK_MM'],
#       dtype='object')
# 1
# Accuracy : 1.0
# Time taken : 2.046363115310669
# Index(['MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation', 'Sunshine',
#        'WindGustSpeed', 'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am',
#        'Humidity3pm', 'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm',
#        'Temp9am', 'Temp3pm', 'RainToday', 'RISK_MM'],
#       dtype='object')
# 2
# Accuracy : 0.8798318748708055
# Time taken : 3.7788617610931396
# Index(['MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation', 'Sunshine',
#        'WindGustSpeed', 'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am',
#        'Humidity3pm', 'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm',
# ...

# %%
import xgboost as xgb
from sklearn import metrics
accs=[]
for x in range(1,6):
    X=new_df.copy()
    X.loc[X["RainToday"]=="Yes","RainToday"]=1
    X.loc[X["RainToday"]=="No","RainToday"]=0
    X["RainToday"]=X["RainToday"].astype("float")
#     X=X[['MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation','Sunshine', 'WindGustSpeed',
#            'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm',
#            'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'Temp9am',
#            'Temp3pm', 'RainToday', 'RISK_MM',"rain_"+str(x)+"_days"]]
    X=X[['Sunshine', 'Humidity9am', 'Humidity3pm','Rainfall',
           'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'Temp9am',
           'Temp3pm',"rain_"+str(x)+"_days"]]
    X=X.dropna()
    y=X["rain_"+str(x)+"_days"]
    del X["rain_"+str(x)+"_days"]
    print(X.columns)
    t0=time.time()
#     X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.25)
#     clf_rf = RandomForestClassifier(n_estimators=100, max_depth=10,random_state=0)
#     clf_rf.fit(X_train,y_train)
#     y_pred = clf_rf.predict(X_test)
#     print('Using following features: \n%s' %df_onehotted.drop(['RainTomorrow_Yes'],axis=1).columns)
    acc_list, b_acc_list, f1_list = [[] for i in range (3)]
    round = 1 # set number of rounds
    print('Running %s rounds. Showing accuracy, balanced accuracy and f1 score...' % round)
    for i in range (round):
        X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2)
        xg = xgb.XGBClassifier(
        objective ='binary:hinge', subsample = 0.9, learning_rate = 0.1,
                max_depth = 8, n_estimators = 300, reg_lambda = 0, reg_alpha = 2).fit(X_train,y_train)
        y_test_predicted = xg.predict(X_test)
        print(i+1,metrics.accuracy_score(y_test,y_test_predicted),metrics.balanced_accuracy_score(y_test,y_test_predicted),metrics.f1_score(y_test,y_test_predicted))
        acc_list.append(metrics.accuracy_score(y_test,y_test_predicted))
        b_acc_list.append(metrics.balanced_accuracy_score(y_test,y_test_predicted))
        f1_list.append(metrics.f1_score(y_test,y_test_predicted))
        print(metrics.confusion_matrix(y_test,y_test_predicted))
        print('australia rainfall dataset: after %s rounds...' % round)
        print('average accuracy:',sum(acc_list)/len(acc_list),'\naverage balanced accuracy:',sum(b_acc_list)/len(b_acc_list),'\naverage f1 score:',sum(f1_list)/len(f1_list))
        accs.append(sum(acc_list)/len(acc_list))
        clf_rf.fit(X,y)
        filename="xgbmodel_"+str(x)
#         pickle.dump(clf_rf, open(filename, 'wb'))
#     print(x)
#     score = accuracy_score(y_test,y_pred)
#     print('Accuracy :',score)
#     print('Time taken :' , time.time()-t0)
# Out:
# Index(['Sunshine', 'Humidity9am', 'Humidity3pm', 'Rainfall', 'Pressure9am',
#        'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'Temp9am', 'Temp3pm'],
#       dtype='object')
# Running 1 rounds. Showing accuracy, balanced accuracy and f1 score...
# 1 0.8537348455220962 0.737867769916474 0.6141147338010731
# [[9427  560]
#  [1310 1488]]
# australia rainfall dataset: after 1 rounds...
# average accuracy: 0.8537348455220962
# average balanced accuracy: 0.737867769916474
# average f1 score: 0.6141147338010731
# Index(['Sunshine', 'Humidity9am', 'Humidity3pm', 'Rainfall', 'Pressure9am',
#        'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'Temp9am', 'Temp3pm'],
#       dtype='object')
# Running 1 rounds. Showing accuracy, balanced accuracy and f1 score...
# 1 0.7727806022682832 0.7243751100013631 0.6338081431992942
# [[7366  972]
#  [1933 2514]]
# australia rainfall dataset: after 1 rounds...
# average accuracy: 0.7727806022682832
# average balanced accuracy: 0.7243751100013631
# ...

# %%
l=0
t=15
for x in range(0,5):
    l=l+accs[x]*((5-x)/15)
print(l)
# Out:
# 0.7706352304369323

# %%
accs
# Out:
# [0.8493246935748302,
#  0.7690686236240144,
#  0.7184791943164962,
#  0.6934967600905613,
#  0.6941993910531657]

# %%
X.dtypes
# Out:
# MinTemp          float64
# MaxTemp          float64
# Rainfall         float64
# Evaporation      float64
# Sunshine         float64
# WindGustSpeed    float64
# WindSpeed9am     float64
# WindSpeed3pm     float64
# Humidity9am      float64
# Humidity3pm      float64
# Pressure9am      float64
# Pressure3pm      float64
# Cloud9am         float64
# Cloud3pm         float64
# Temp9am          float64
# Temp3pm          float64
# RainToday         object
# RISK_MM          float64
# dtype: object

# %%
X=new_df.copy()

# %%
# Out:
# 0.28913562538016685
